# %%
print("Succes!")
# Out:
# Succes!

# %%
1
0x32BA
# Out:
# 12986

# %%
# titlu
print( bin (2026) )
print( hex(2026) )
print( oct(2026) )
# Out:
# 0b11111101010
# 0x7ea
# 0o3752

# %% [markdown]
# # Titlu Mare

# %% [markdown]
# 2.4

# %%
2,4 
2.4 #virgula indicata prin caracterul punct
2.4e-3 #exponentul indicat prin caracterul e sau E
print( 2.4e-3 )
# Out:
# 0.0024

# %%
2.4 #virgula indicata prin caracterul punct
# Out:
# 2.4

# %%
2,4
# Out:
# (2, 4)

# %%
#functia de rotunjire:
round(-1.24,0) #rotunjire la 0 zecimale
round(-1.24,1) #rotunjire la 1 zecimala 
print(round(-1.24, 0)) # va afișa -1.0
print(round(-1.24, 1)) # va afișa -1.2
# Out:
# -1.0
# -1.2

# %% [markdown]
# ### Date de tip 'complex'

# %%
(4+5j).imag #punctul face legatura intre partea reala si cea imaginara a numarului complex
# Out:
# 5.0

# %%
(-3+9j).real #partea reala a numarului complex
# Out:
# -3.0

# %% [markdown]
# ### date de tip boolean: 'bool'

# %%
True
# Out:
# True

# %%
True+True  #de nerecomandat, dar se poate face
# Out:
# 2

# %% [markdown]
# ## Siruri de caractere: str

# %%
"" # sir de caractere gol
# Out:
# ''

# %%
f'rezultatul este {2+3}' #f-string, permite includerea expresiilor in interiorul sirului de caractere
# Out:
# 'rezultatul este 5'

# %%
nume = "Alex"
f"Salut, {nume}!"
# Out:
# 'Salut, Alex!'

# %%
x=7
print(x)
# Out:
# 7

# %%
x=7 # sintaxa incorecta, nu se poate declara o variabila cu tipul de date in fata
x=2.5 # nu se foloseste punctul si virgula la sfarsitul liniei in Python

# %%
print(x)
# Out:
# 2.5

# %%
#id ul obiectelor:
x=7
id(x) #id ul obiectului x, adica adresa de memorie unde este stocat valoarea 7
print(id(x))
x=2.5
id(x) #id ul obiectului x, adica adresa de memorie unde este
print(id(x))
# Out:
# 140727102166328
# 2784513146384

# %%
#functia return tipul unei variabile(obiectului)
type(x) #tipul de date al variabilei x, adica float
# Out:
# float

# %%
rez=max(3,5,7) #functia max returneaza valoarea maxima dintre cele 3 argumente
type(rez)
# Out:
# int

# %% [markdown]
# # Sfarsit curs 1
