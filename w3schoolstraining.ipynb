# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
import sys

print(sys.version)
# Out:
# 3.14.3 (tags/v3.14.3:323c59a, Feb  3 2026, 16:04:56) [MSC v.1944 64 bit (AMD64)]

# %% [markdown]
# ## Python Indentation

# %% [markdown]
# Where in other programming languages the indentation in code is for readability only, the indentation in Python is very important.

# %%
if 5 > 2:
  print("Five is greater than two!")
# Out:
# Five is greater than two!

# %% [markdown]
# if 5 > 2:
# print("Five is greater than two!")  %%sintax error: expected an indented block after 'if' statement on line 5

# %% [markdown]
# ### Python Variables

# %%
x = 5
y = "Hello, World!"
print(x)
print(y)
# Out:
# 5
# Hello, World!

# %% [markdown]
# ### Comments

# %%
#This is a comment.
print("Comentariile incep cu #")
# Out:
# Comentariile incep cu #
