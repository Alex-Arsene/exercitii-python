# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
import sys

print(sys.version)
# Out:
# 3.14.3 (tags/v3.14.3:323c59a, Feb  3 2026, 16:04:56) [MSC v.1944 64 bit (AMD64)]

# %% [markdown]
# ## Python Indentation

# %% [markdown]
# Where in other programming languages the indentation in code is for readability only, the indentation in Python is very important.

# %%
if 5 > 2:
    print("Five is greater than two!")
# Out:
# Five is greater than two!

# %% [markdown]
# ### Python Variables

# %%
x = 5
y = "Hello, World!"
print(x)
print(y)
# Out:
# 5
# Hello, World!

# %% [markdown]
# ### Comments

# %%
#This is a comment.
print("Comentariile incep cu #")
# Out:
# Comentariile incep cu #

# %%
print("Hello"); print("How are you?"); print("Bye bye!")
# Out:
# Hello
# How are you?
# Bye bye!

# %%
print("Semicolons are optional in Python. You can write multiple statements on one line by separating them with ; but this is rarely used because it makes it hard to read:")
# Out:
# Semicolons are optional in Python. You can write multiple statements on one line by separating them with ; but this is rarely used because it makes it hard to read:

# %%
print("Hello World!", end=" ")
print("I will print on the same line.")
# Out:
# Hello World! I will print on the same line.

# %%
print("I am", 2026-2005, "years old.")
# Out:
# I am 21 years old.

# %% [markdown]
# ## Get the Type
# ### You can get the data type of a variable with the type() function.

# %%
x = 5
y = "John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
print("Acum sunt pe pagina separata (create new brunch)")
# Out:
# Acum sunt pe pagina separata (create new brunch)

# %% [markdown]
# ## Ziua 3 de Python

# %% [markdown]
# ### variabilele in python

# %%
MyVariableName="FCSB"
if 5>2:
    print(MyVariableName)
# Out:
# FCSB

# %%
locu1,locu2,locu3="FCSB","Steaua","Steaua Bucuresti"
print(locu1)
print(locu2)
# Out:
# FCSB
# Steaua

# %%
FCSB=STEAUA="Echipa mea de suflet"
print(STEAUA)
# Out:
# Echipa mea de suflet

# %%
fructe=["mere","pere","cirese"]
x,y,z=fructe
print(x)
print(y)
print(z)
# Out:
# mere
# pere
# cirese

# %%
x = 5
y = "John"
print(x, y)
# Out:
# 5 John

# %% [markdown]
# ### variabile globale

# %%
print("Variabilele globale sunt create în afara unei funcții și pot fi utilizate oriunde în program, inclusiv în interiorul funcțiilor. Variabilele locale sunt create în interiorul unei funcții și pot fi utilizate doar în acea funcție.")
# Out:
# Variabilele globale sunt create în afara unei funcții și pot fi utilizate oriunde în program, inclusiv în interiorul funcțiilor. Variabilele locale sunt create în interiorul unei funcții și pot fi utilizate doar în acea funcție.

# %%
x="merge"
def myfunc():
    global x
    print("Python is " + x)
myfunc()
# Out:
# Python is merge

# %%
y="creez"
def functiamea():
    global y
    print("Astazi " + y + " o noua functie cu variabila globala")
functiamea()
# Out:
# Astazi creez o noua functie cu variabila globala

# %%
x = "bun"

def myfunc():
  x = "superb"
  print("Python is " + x)

myfunc()

print("Python is " + x)
# Out:
# Python is superb
# Python is bun

# %%
def functia():
    global x
    x = "superb"
functia()
print("Python is " + x)
# Out:
# Python is superb

# %%
x="Variabila globala normala inainte de functie"
def func():
    global x
    x="Variabila globala modificata in functie"
func()
print(x)
# Out:
# Variabila globala modificata in functie

# %% [markdown]
# ### variabilele python se pot converti de la un tip la altul folosind int(), float() sau complex().

# %%
x=1
print(type(x))
a=float(x)
print(type(a))
# Out:
# <class 'int'>
# <class 'float'>

# %%
import random
print(random.randrange(1, 10))
if random.randrange(1, 10) == 5:
    print("Am ghicit numarul 5!")
else :
    print("Nu am ghicit numarul 5!")
# Out:
# 7
# Nu am ghicit numarul 5!

# %% [markdown]
# ### In python sirurile de caractere sunt vectori

# %%
a="Hello, World!"
print(a[1])
print(a[2:5])
# Out:
# e
# llo

# %%
for x in  "i love python":
    print(x)
# Out:
# i
#
# l
# o
# v
# e
#
# p
# y
# t
# h
# o
# n

# %%
x="Python iS great"
print(len(x))
print("great" in x) #verifica daca great se afla in x
if "great" in x:
    print("Da, 'great' se afla in x")
print("super" in x)
print("super" not in x) #verifica daca super nu se afla in x
if "super" not in x:
    print("Nu, 'super' nu se afla in x")
print(x.upper()) # - transforma stringul in majuscule")
a = " Hello, World! "
print(a.strip()) # - sterge spatiile de la inceputul si sfarsitul stringului
print(a.replace("H", "J")) # - inlocuieste H cu J
print(x.split(" ")) # - imparte stringul in functie de separatorul dat, in acest caz virgula
print(a + x) # - concateneaza stringurile a si x
print(a + " forta steaua! " + x) # - concateneaza stringurile a si x cu un spatiu intre ele
perioada=5
txt=f"invat python de {perioada:.3f} zile"
print(txt)
txt.capitalize() # - transforma primul caracter in majuscula
# Out:
# 15
# True
# Da, 'great' se afla in x
# False
# True
# Nu, 'super' nu se afla in x
# PYTHON IS GREAT
# Hello, World!
#  Jello, World!
# ['Python', 'iS', 'great']
#  Hello, World! Python iS great
#  Hello, World!  forta steaua! Python iS great
# invat python de 5.000 zile
# 'Invat python de 5.000 zile'

# %% [markdown]
# ### Python Booleans

# %%
if 10>9:
    print("Booleans represent one of two values: True or False.")
# Out:
# Booleans represent one of two values: True or False.

# %%
print(10 > 9)
print(10 == 9)
print(10 < 9)
# Out:
# True
# False
# False

# %%
a=2005
b=234
if a>b:
    print("a is greater than b")
def func():
    a=3000
    if a>2*b:
        print("a is greater than 2*b")
func()
# Out:
# a is greater than b
# a is greater than 2*b

# %%
print(bool("Hello"))
print(bool(15))
print(bool(""))
print(bool(0))
print(10>9)
# Out:
# True
# True
# False
# False
# True

# %%
def functie():
    return True 
if functie():#linia devine practic if True
    print("Yes, it is true")
else:
    print("No, it is false")
# Out:
# Yes, it is true

# %%
x=200.3
print(isinstance(x, int))
print(isinstance(x, float))
# Out:
# False
# True

# %%
num=[1,2,3,4,5]
if(count:=len(num))>4:
    print(f"List has {count} elements")
# Out:
# List has 5 elements

# %%
print(6&3)
"""
The binary representation of 6 is 0110
The binary representation of 3 is 0011

Then the & operator compares the bits and returns 0010, which is 2 in decimal.
"""
print(6|3) ### 0111
print(6^3) ### 0101
# Out:
# 2
# 7
# 5

# %% [markdown]
# ### 28.02.2026
# ##

# %% [markdown]
# ### python operators

# %%
a=15
b=4
print(a // b) # - returneaza catul impartirii a la b, adica 3 fara virgula
print(a % b) # - returneaza restul impartirii a la b, adica 3
print(a ** b) # - returneaza a la puterea b, adica 15 la puterea 4
# Out:
# 3
# 3
# 50625

# %% [markdown]
# ### python lists

# %%
lista=["mere", "masini", 1]
print(f"Lista mea este: {lista}") # - afiseaza lista mea folosind f-string pentru a include variabila lista in stringul de afisat
print(f"Lista are {len(lista)} elemente")
lista1=['alex', True, 1]
print(f"lista este {lista1}")
print(type(lista))
listacomplexa= list(("mar","paine", 1))
print(f"{listacomplexa} si {listacomplexa[1]}")
if "irina" in lista1:
    print("nu")
else:
    print("atunci nu e nici alex")
lista1[1]= "Irina"
lista1.insert(2,"iubire")
lista1.append(2)
print(lista1)
lista1.extend(lista)
print(lista1)
for i in range(len(lista1)):
    print(lista1[i])
# Out:
# Lista mea este: ['mere', 'masini', 1]
# Lista are 3 elemente
# lista este ['alex', True, 1]
# <class 'list'>
# ['mar', 'paine', 1] si paine
# atunci nu e nici alex
# ['alex', 'Irina', 'iubire', 1, 2]
# ['alex', 'Irina', 'iubire', 1, 2, 'mere', 'masini', 1]
# alex
# Irina
# iubire
# 1
# 2
# mere
# masini
# 1

# %%
thislist = ["apple", "banana", "cherry"]
i = 0
while i < len(thislist):
  print(thislist[i])
  i = i + 1

for x in thislist:
  print(x)

# e acelasi lucru cu 
(print(x) for x in thislist)
# Out:
# apple
# banana
# cherry
# apple
# banana
# cherry
# <generator object <genexpr> at 0x0000018B5E79ECE0>

# %% [markdown]
# ##### list comprehension

# %%
thislist = ["apple", "banana", "cherry"]
newlist=[x for x in thislist if "a" in x]
print(newlist)
newlist2=[x for x in thislist if x!="banana"]
print(newlist2)
newlist3=[x if x!="banana" else "orange" for x in thislist]
print(newlist3) #apple daca apple diferit de banana alfel orange  pentru altfel, nu e cazul
# Out:
# ['apple', 'banana']
# ['apple', 'cherry']
# ['apple', 'orange', 'cherry']

# %% [markdown]
# ##### sort list

# %%
thislist = ["apple", "cherry", "banana"]
print(thislist)
thislist.sort()
print(thislist)
thislist.sort(reverse=True)
print(thislist)
thislist2 = ["apple", "Cherry", "banana"]
thislist2.sort(key=str.lower)
print(thislist2)
thislist2.reverse()
print(thislist2)
# Out:
# ['apple', 'cherry', 'banana']
# ['apple', 'banana', 'cherry']
# ['cherry', 'banana', 'apple']
# ['apple', 'banana', 'Cherry']
# ['Cherry', 'banana', 'apple']

# %% [markdown]
# ##### copy a list

# %%
thislist = ["apple", "cherry", "banana"]
mylist=thislist.copy()
thatlist=list(thislist)
print(mylist, thatlist)
# Out:
# ['apple', 'cherry', 'banana'] ['apple', 'cherry', 'banana']

# %% [markdown]
# #### list methods

# %% [markdown]
#  append()	Adds an element at the end of the list
# clear()	Removes all the elements from the list
# copy()	Returns a copy of the list
# count()	Returns the number of elements with the specified value
# extend()	Add the elements of a list (or any iterable), to the end of the current list
# index()	Returns the index of the first element with the specified value
# insert()	Adds an element at the specified position
# pop()	Removes the element at the specified position
# remove()	Removes the item with the specified value
# reverse()	Reverses the order of the list
# sort()	Sorts the list

# %%
# Create a list
colors = ["red", "green", "blue"]

# Print the first item
print(colors[0])

# Change the second item to "yellow"
colors[1] = "yellow"

# Add "purple" to the end
colors.append("purple")

# Remove "red"
colors.remove("red")

# Print the list
print(colors)
# Out:
# red
# ['yellow', 'blue', 'purple']
